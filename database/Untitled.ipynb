# %%
import pandas as pd

# %%
df = pd.read_csv('no_nan_data')

# %%
df.head()
# Out:
#    Unnamed: 0  id       strain  \
# 0           0   1   sugar-cane
# 1           1   2     chemdawg
# 2           2   3   jack-herer
# 3           3   4  green-dream
# 4           4   5  lemon-skunk
#
#                                               effect  \
# 0  Body High, Cerebral, Creative, Energetic, Rela...
# 1  Cerebral, Creative, Euphoric, Happy, Relaxed, ...
# 2  Body High, Cerebral, Creative, Energetic, Euph...
# 3  Creative, Energetic, Euphoric, Happy, Hungry, ...
# 4  Energetic, Euphoric, Focused, Giggly, Happy, R...
#
#                                               target  \
# 0        Analgesic, Antibacterial, Anti inflammatory
# 1  Analgesic, Antibacterial, Antidepressant, Anti...
# 2  Analgesic, Antibacterial, Antidepressant, Anti...
# 3  Analgesic, Anti epileptic, Anti inflammatory, ...
# 4  Analgesic, Antibacterial, Antidepressant, Anti...
#
#                                               flavor    Type  Percent Indica  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'strain', 'effect', 'target', 'flavor', 'Type',
#        'Percent Indica', 'Percent Sativa', 'THC Percent', 'Description 1',
#        'Description 2', 'Generated Description', 'Rating', 'labs',
#        'cis-Nerolidol', 'trans-Nerolidol', 'trans-Nerolidol 1',
#        'trans-Nerolidol 2', 'trans-Ocimene', '3-Carene', 'Camphene',
#        'Caryophyllene Oxide', 'Eucalyptol', 'Geraniol', 'Guaiol', 'Isopulegol',
#        'Linalool', 'Ocimene', 'Terpinolene', 'alpha-Bisabolol',
#        'alpha-Humulene', 'alpha-Pinene', 'alpha-Terpinene',
#        'beta-Caryophyllene', 'beta-Myrcene', 'beta-Ocimene', 'beta-Pinene',
#        'delta-Limonene', 'gamma-Terpinene', 'p-Cymene', 'delta-9 THC-A',
#        'delta-9 THC', 'delta-8 THC', 'THC-A', 'THCV', 'CBN', 'CBD-A', 'CBD',
#        'CBDV', 'CBDV-A', 'delta-9 CBG-A', 'delta-9 CBG', 'CBC',
#        'Moisture Content', 'ana360', 'psilabs', 'sclabs'],
#       dtype='object')

# %%
columns = df.columns

# %%
needed_columns = ['strain', 'effect', 'target', 'flavor', 'Type', 'THC Percent',
                  'CBD', 'Description 1']

# %%
not_needed = []

for item1 in columns:
    if item1 not in needed_columns:
        not_needed.append(item1)

# %%
not_needed
# Out:
# ['Unnamed: 0',
#  'id',
#  'Percent Indica',
#  'Percent Sativa',
#  'Description 2',
#  'Generated Description',
#  'Rating',
#  'labs',
#  'cis-Nerolidol',
#  'trans-Nerolidol',
#  'trans-Nerolidol 1',
#  'trans-Nerolidol 2',
#  'trans-Ocimene',
#  '3-Carene',
#  'Camphene',
#  'Caryophyllene Oxide',
#  'Eucalyptol',
#  'Geraniol',
#  'Guaiol',
#  'Isopulegol',
#  'Linalool',
#  'Ocimene',
#  'Terpinolene',
#  'alpha-Bisabolol',
#  'alpha-Humulene',
#  'alpha-Pinene',
#  'alpha-Terpinene',
#  'beta-Caryophyllene',
#  'beta-Myrcene',
#  'beta-Ocimene',
#  'beta-Pinene',
#  'delta-Limonene',
#  'gamma-Terpinene',
#  'p-Cymene',
#  'delta-9 THC-A',
#  'delta-9 THC',
#  'delta-8 THC',
#  'THC-A',
#  'THCV',
#  'CBN',
#  'CBD-A',
#  'CBDV',
#  'CBDV-A',
#  'delta-9 CBG-A',
#  'delta-9 CBG',
#  'CBC',
#  'Moisture Content',
#  'ana360',
#  'psilabs',
#  'sclabs']
